# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('C:\\Users\\vishesh\\Downloads\\Salaries.csv')
df.drop(['rank'], axis=1).plot.line(title='Line graph example',figsize=(15,5))
plt.ylabel('phd')
plt.xlabel('service')
plt.show()
